# %%
#Performing the visualization on Data by using PAndas and Matplotlib

# %%
import pandas as pd

# Load the dataset
df=pd.read_csv("Athletes.csv")

# Display the first few rows of the dataset
print(df.head())
# Out:
#                 Name     NOC           Discipline
# 0    AALERUD Katrine  Norway         Cycling Road
# 1        ABAD Nestor   Spain  Artistic Gymnastics
# 2  ABAGNALE Giovanni   Italy               Rowing
# 3     ABALDE Alberto   Spain           Basketball
# 4      ABALDE Tamara   Spain           Basketball

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# Name          0
# NOC           0
# Discipline    0
# dtype: int64

# %%
df.describe()
# Out:
#              Name                       NOC Discipline
# count       11085                     11085      11085
# unique      11062                       206         46
# top     CHEN Yang  United States of America  Athletics
# freq            2                       615       2068

# %%
# Summary statistics
print(df.describe())

print("Unique Games:", df['Name'].unique())
print("Unique Sport:", df['NOC'].unique())
# Out:
#              Name                       NOC Discipline
# count       11085                     11085      11085
# unique      11062                       206         46
# top     CHEN Yang  United States of America  Athletics
# freq            2                       615       2068
# Unique Games: ['AALERUD Katrine' 'ABAD Nestor' 'ABAGNALE Giovanni' ... 'ZYKOVA Yulia'
#  'ZYUZINA Ekaterina' 'ZYZANSKA Sylwia']
# Unique Sport: ['Norway' 'Spain' 'Italy' 'France' 'Chile' 'Sudan'
#  'Islamic Republic of Iran' 'Azerbaijan' 'Netherlands' 'Australia'
#  'United States of America' 'Qatar' 'Egypt' 'Belgium' 'Malaysia'
#  'Singapore' 'Maldives' 'Saudi Arabia' 'Germany' 'Uzbekistan' 'Indonesia'
#  'Kazakhstan' 'Bahrain' 'Japan' 'Ethiopia' 'Canada' 'Malta' 'Sri Lanka'
#  'Morocco' 'Austria' 'Mauritania' 'ROC' 'Libya' 'Nauru' 'Switzerland'
#  'South Africa' 'Guyana' 'Georgia' 'Portugal' 'Jordan' 'Palestine' 'India'
#  'Cyprus' 'Nigeria' 'Tunisia' 'Mexico' 'Colombia' 'El Salvador' 'Romania'
# ...

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Name', order=df['Name'].value_counts().index[:10], palette='Set2')
plt.title('Top 10 Athletes by Name')
plt.xlabel('Athlete Name')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, y='Discipline', order=df['Discipline'].value_counts().index[:10], palette='Set1')
plt.title('Top 10 Disciplines with the Most Athletes')
plt.xlabel('Number of Athletes')
plt.ylabel('Discipline')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Name', order=df['Name'].value_counts().index[:10], palette='Set2')
plt.title('Top 10 Athletes by Name')
plt.xlabel('Athlete Name')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
