# %% [markdown]
# <html>
# <body>
# <h1 align="center"><font color="red">Data Analysis and Visualization</font></h1>
# <h2 font color="blue">M.Suresh-G8DS</font></h2>
# </body>
# </html>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
athletes=pd.read_excel("Athletes.xlsx")

# %%
athletes.head()
# Out:
#                 Name     NOC           Discipline
# 0    AALERUD Katrine  Norway         Cycling Road
# 1        ABAD Nestor   Spain  Artistic Gymnastics
# 2  ABAGNALE Giovanni   Italy               Rowing
# 3     ABALDE Alberto   Spain           Basketball
# 4      ABALDE Tamara   Spain           Basketball

# %%
athletes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11085 entries, 0 to 11084
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        11085 non-null  object
#  1   NOC         11085 non-null  object
#  2   Discipline  11085 non-null  object
# dtypes: object(3)
# memory usage: 259.9+ KB

# %%
athletes.isna()
# Out:
#         Name    NOC  Discipline
# 0      False  False       False
# 1      False  False       False
# 2      False  False       False
# 3      False  False       False
# 4      False  False       False
# ...      ...    ...         ...
# 11080  False  False       False
# 11081  False  False       False
# 11082  False  False       False
# 11083  False  False       False
# 11084  False  False       False
#
# [11085 rows x 3 columns]

# %%
athletes.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11080    False
# 11081    False
# 11082    False
# 11083    False
# 11084    False
# Length: 11085, dtype: bool

# %% [markdown]
# # Number of Athletes in each country

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.countplot(x='NOC', data=athletes[:20], palette='viridis')

plt.title('Total Number of Athletes in Each NOC')
plt.xlabel('NOC')
plt.ylabel('Number of Athletes in 100s')

# Adding a legend


plt.show()

# %% [markdown]
# <h2><font color="blue">Number of athletes in each discipline</font></h2>

# %%
plt.figure(figsize=(10,10))
athletes['Discipline'].value_counts().plot(kind="bar",color="g")
plt.title("Number of athletes in each discipline")
plt.show()

# %% [markdown]
# <h2><font color="green">Distribution of Disciplines in particular counter</font></h2>

# %%
india_data =athletes[athletes['NOC'] == 'India']
discipline_counts = india_data['Discipline'].value_counts()

# Plotting
plt.figure(figsize=(10, 6))
discipline_counts.plot(kind='barh', color='r')
plt.title('Distribution of Disciplines in India',weight="bold")
plt.ylabel('Discipline')
plt.xlabel('Count')
plt.show()

# %%
medals=pd.read_excel("Medals.xlsx")
# Out:
# /home/apiiit123/anaconda3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
medals.head()
# Out:
#    Rank                    Team/NOC  Gold  Silver  Bronze  Total  \
# 0     1    United States of America    39      41      33    113
# 1     2  People's Republic of China    38      32      18     88
# 2     3                       Japan    27      14      17     58
# 3     4               Great Britain    22      21      22     65
# 4     5                         ROC    20      28      23     71
#
#    Rank by Total
# 0              1
# 1              2
# 2              5
# 3              4
# 4              3

# %%
medals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           93 non-null     int64
#  1   Team/NOC       93 non-null     object
#  2   Gold           93 non-null     int64
#  3   Silver         93 non-null     int64
#  4   Bronze         93 non-null     int64
#  5   Total          93 non-null     int64
#  6   Rank by Total  93 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 5.2+ KB

# %%
medals.isna()
# Out:
#      Rank  Team/NOC   Gold  Silver  Bronze  Total  Rank by Total
# 0   False     False  False   False   False  False          False
# 1   False     False  False   False   False  False          False
# 2   False     False  False   False   False  False          False
# 3   False     False  False   False   False  False          False
# 4   False     False  False   False   False  False          False
# ..    ...       ...    ...     ...     ...    ...            ...
# 88  False     False  False   False   False  False          False
# 89  False     False  False   False   False  False          False
# 90  False     False  False   False   False  False          False
# 91  False     False  False   False   False  False          False
# 92  False     False  False   False   False  False          False
#
# [93 rows x 7 columns]

# %% [markdown]
# # Total medals for each country

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'medals' is your DataFrame with the given columns
# Replace 'Team/NOC' and 'Total' with your actual column names

plt.figure(figsize=(20,10))
plt.bar(x=medals['Team/NOC'],height=medals['Total'], color='purple')
plt.xlabel('Country')
plt.ylabel('Total Medals')
plt.title('Total Medals for Each Country')
plt.xticks(rotation=90) 
plt.show()

# %% [markdown]
# <h2 style color="green">Top 10 countries with Medals</h2>

# %%
A = plt.pie(medals['Total'][:10], 
        labels=medals['Team/NOC'][:10],
        startangle=90,
        autopct='%1.1f%%')
plt.title("Pie Chart of Top 10 Countries with Medals",weight="bold")
plt.show()

# %% [markdown]
# # Number of medals a particular country won

# %%
country=medals[medals['Team/NOC'] == 'India']

gold=country['Gold'].sum()
silver=country['Silver'].sum()
bronze=country['Bronze'].sum()

medal_counts = [gold, silver, bronze]
medal_labels = ['Gold', 'Silver', 'Bronze']


plt.figure(figsize=(4,4))
plt.pie(medal_counts,labels=medal_labels, autopct='%1.1f%%')
plt.legend(loc="upper right")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(12, 6))


sns.distplot(medals['Gold'],color='red', label='Gold')

sns.distplot(medals['Silver'],color='blue', label='Silver')

sns.distplot(medals['Bronze'],color='brown', label='Bronze')

plt.title('Distribution of Gold,Silver and Bronze Medals')
plt.xlabel('Number of Medals')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_6371/655155069.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(medals['Gold'],color='red', label='Gold')
# /tmp/ipykernel_6371/655155069.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(medals['Silver'],color='blue', label='Silver')
# ...

# %% [markdown]
# # Pairplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(1,4))


subset = medals[['Gold', 'Silver', 'Bronze']]
sns.pairplot(subset, palette='viridis')
plt.suptitle('Pair Plot of Gold, Silver, Bronze Medals', y=1.02)
plt.show()
# Out:
# /home/apiiit123/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /home/apiiit123/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /home/apiiit123/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /home/apiiit123/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:1609: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# /home/apiiit123/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:1609: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# ...
